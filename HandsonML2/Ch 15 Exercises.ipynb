# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
    IS_COLAB = True
except Exception:
    IS_COLAB = False

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

if not tf.test.is_gpu_available():
    print("No GPU was detected. LSTMs and CNNs can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware accelerator.")

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "rnn"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
# Out:
# No GPU was detected. LSTMs and CNNs can be very slow without a GPU.

# %%
DATA_DIR = os.path.join(PROJECT_ROOT_DIR,"datasets","jsb_chorales")

train_files = [os.path.join(DATA_DIR,"train",x) for x in os.listdir(os.path.join(DATA_DIR,"train"))]
test_files = [os.path.join(DATA_DIR,"test",x) for x in os.listdir(os.path.join(DATA_DIR,"test"))]
valid_files = [os.path.join(DATA_DIR,"valid",x) for x in os.listdir(os.path.join(DATA_DIR,"valid"))]
train_files
# Out:
# ['.\\datasets\\jsb_chorales\\train\\chorale_000.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_001.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_002.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_003.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_004.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_005.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_006.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_007.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_008.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_009.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_010.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_011.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_012.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_013.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_014.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_015.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_016.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_017.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_018.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_019.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_020.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_021.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_022.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_023.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_024.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_025.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_026.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_027.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_028.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_029.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_030.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_031.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_032.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_033.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_034.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_035.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_036.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_037.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_038.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_039.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_040.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_041.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_042.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_043.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_044.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_045.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_046.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_047.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_048.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_049.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_050.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_051.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_052.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_053.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_054.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_055.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_056.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_057.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_058.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_059.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_060.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_061.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_062.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_063.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_064.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_065.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_066.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_067.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_068.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_069.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_070.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_071.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_072.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_073.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_074.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_075.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_076.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_077.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_078.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_079.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_080.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_081.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_082.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_083.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_084.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_085.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_086.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_087.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_088.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_089.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_090.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_091.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_092.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_093.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_094.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_095.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_096.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_097.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_098.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_099.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_100.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_101.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_102.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_103.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_104.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_105.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_106.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_107.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_108.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_109.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_110.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_111.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_112.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_113.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_114.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_115.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_116.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_117.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_118.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_119.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_120.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_121.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_122.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_123.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_124.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_125.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_126.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_127.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_128.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_129.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_130.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_131.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_132.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_133.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_134.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_135.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_136.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_137.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_138.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_139.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_140.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_141.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_142.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_143.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_144.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_145.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_146.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_147.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_148.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_149.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_150.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_151.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_152.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_153.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_154.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_155.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_156.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_157.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_158.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_159.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_160.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_161.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_162.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_163.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_164.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_165.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_166.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_167.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_168.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_169.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_170.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_171.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_172.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_173.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_174.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_175.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_176.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_177.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_178.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_179.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_180.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_181.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_182.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_183.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_184.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_185.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_186.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_187.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_188.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_189.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_190.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_191.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_192.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_193.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_194.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_195.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_196.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_197.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_198.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_199.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_200.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_201.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_202.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_203.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_204.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_205.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_206.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_207.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_208.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_209.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_210.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_211.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_212.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_213.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_214.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_215.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_216.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_217.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_218.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_219.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_220.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_221.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_222.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_223.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_224.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_225.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_226.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_227.csv',
#  '.\\datasets\\jsb_chorales\\train\\chorale_228.csv']

# %%
def preprocess(line):
    defs = [0] * 4 + [tf.constant([], dtype=tf.float32)]
    print("Defaults ",defs)
    fields = tf.io.decode_csv(line, record_defaults=defs)

# %%
train_files_set = tf.data.Dataset.list_files(train_files, seed=13)
valid_files_set = tf.data.Dataset.list_files(valid_files, seed=13)

# %%
import pandas as pd

sample = pd.read_csv(train_files[1])
train_files_set
# Out:
# <DatasetV1Adapter shapes: (), types: tf.string>

# %%
print("training set size: ",len(train_files))
print("validation set size: ",len(valid_files))
print("test set size: ",len(test_files))
# Out:
# training set size:  229
# validation set size:  76
# test set size:  77

# %%
# TODO: need to chop each file into batches of time steps?
# use tf.data.Dataset.window to create windows.
# Split chords into sequences of tones to improve harmonic relations
# Use embeddings to get better harmonic relations

# Lowest note is 36, highest is 81
# Shift notes by the smallest note to get values from 1(0)-46
# Keep silences (=0) as they are
def preprocess_chords(chords):
    chords = tf.reshape(chords, [-1])
    chords.where(chords==0, chords, chords - 35)
    
def extract_target(batch):
    X = batch[:, :-1]
    Y = batch[:, 1:]
    return X, Y
    
def preprocess_and_batch(chorales, window_size=32, window_shift=16, batch_size=32):
    
    # Helper function for creating windows, batching and returning in flattened form
    def create_window(chorales):
        dataset = tf.data.Dataset.from_tensor_slices(chorales)
        dataset = dataset.window(window_size+1,window_shift,1,True)
        return dataset.flat_map(lambda x: Dataset.batch(x))
    
    # Create ragged tensor from data, reshape into 1D array and apply preprocessing,
    # finally batch the data and extract target steps
    chorales = tf.ragged.constant(chorales, ragged_rank=1)
    print("chorales:",chorales)
    chorale_ds = tf.data.Dataset.from_tensor_slices(chorales)
    print(chorale_ds.element_spec)
    chorale_ds = chorale_ds.flat_map(create_window).map(preprocess_chords)                              
    chorale_ds = chorale_ds.batch(batch_size)
    chorale_ds = chorale_ds.map(extract_target)
    
    return chorale_ds.prefetch(1)

# %%
def open_data_files(file_paths):
    return [pd.read_csv(file_path).values.tolist() for file_path in file_paths]

# TODO: load all sets with function above
train_data = open_data_files(train_files)
valid_data = open_data_files(valid_files)
test_data = open_data_files(test_files)

train_data[0]
# Out:
# [[74, 70, 65, 58],
#  [74, 70, 65, 58],
#  [74, 70, 65, 58],
#  [74, 70, 65, 58],
#  [75, 70, 58, 55],
#  [75, 70, 58, 55],
#  [75, 70, 60, 55],
#  [75, 70, 60, 55],
#  [77, 69, 62, 50],
#  [77, 69, 62, 50],
#  [77, 69, 62, 50],
#  [77, 69, 62, 50],
#  [77, 70, 62, 55],
#  [77, 70, 62, 55],
#  [77, 69, 62, 55],
#  [77, 69, 62, 55],
#  [75, 67, 63, 48],
#  [75, 67, 63, 48],
#  [75, 69, 63, 48],
#  [75, 69, 63, 48],
#  [74, 70, 65, 46],
#  [74, 70, 65, 46],
#  [74, 70, 65, 46],
#  [74, 70, 65, 46],
#  [72, 69, 65, 53],
#  [72, 69, 65, 53],
#  [72, 69, 65, 53],
#  [72, 69, 65, 53],
#  [72, 69, 65, 53],
#  [72, 69, 65, 53],
#  [72, 69, 65, 53],
#  [72, 69, 65, 53],
#  [74, 70, 65, 46],
#  [74, 70, 65, 46],
#  [74, 70, 65, 46],
#  [74, 70, 65, 46],
#  [75, 69, 63, 48],
#  [75, 69, 63, 48],
#  [75, 67, 63, 48],
#  [75, 67, 63, 48],
#  [77, 65, 62, 50],
#  [77, 65, 62, 50],
#  [77, 65, 60, 50],
#  [77, 65, 60, 50],
#  [74, 67, 58, 55],
#  [74, 67, 58, 55],
#  [74, 67, 58, 53],
#  [74, 67, 58, 53],
#  [72, 67, 58, 51],
#  [72, 67, 58, 51],
#  [72, 67, 58, 51],
#  [72, 67, 58, 51],
#  [72, 65, 57, 53],
#  [72, 65, 57, 53],
#  [72, 65, 57, 53],
#  [72, 65, 57, 53],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46],
#  [72, 69, 65, 53],
#  [72, 69, 65, 53],
#  [72, 69, 65, 53],
#  [72, 69, 65, 53],
#  [74, 71, 53, 50],
#  [74, 71, 53, 50],
#  [74, 71, 53, 50],
#  [74, 71, 53, 50],
#  [75, 72, 55, 48],
#  [75, 72, 55, 48],
#  [75, 72, 55, 50],
#  [75, 72, 55, 50],
#  [75, 67, 60, 51],
#  [75, 67, 60, 51],
#  [75, 67, 60, 53],
#  [75, 67, 60, 53],
#  [74, 67, 60, 55],
#  [74, 67, 60, 55],
#  [74, 67, 57, 55],
#  [74, 67, 57, 55],
#  [74, 65, 59, 43],
#  [74, 65, 59, 43],
#  [72, 63, 59, 43],
#  [72, 63, 59, 43],
#  [72, 63, 55, 48],
#  [72, 63, 55, 48],
#  [72, 63, 55, 48],
#  [72, 63, 55, 48],
#  [72, 63, 55, 48],
#  [72, 63, 55, 48],
#  [72, 63, 55, 48],
#  [72, 63, 55, 48],
#  [75, 67, 60, 60],
#  [75, 67, 60, 60],
#  [75, 67, 60, 60],
#  [75, 67, 60, 60],
#  [77, 70, 62, 58],
#  [77, 70, 62, 58],
#  [77, 70, 62, 56],
#  [77, 70, 62, 56],
#  [79, 70, 62, 55],
#  [79, 70, 62, 55],
#  [79, 70, 62, 53],
#  [79, 70, 62, 53],
#  [79, 70, 63, 51],
#  [79, 70, 63, 51],
#  [79, 70, 63, 51],
#  [79, 70, 63, 51],
#  [77, 70, 63, 58],
#  [77, 70, 63, 58],
#  [77, 70, 60, 58],
#  [77, 70, 60, 58],
#  [77, 70, 62, 46],
#  [77, 70, 62, 46],
#  [77, 68, 62, 46],
#  [75, 68, 62, 46],
#  [75, 67, 58, 51],
#  [75, 67, 58, 51],
#  [75, 67, 58, 51],
#  [75, 67, 58, 51],
#  [75, 67, 58, 51],
#  [75, 67, 58, 51],
#  [75, 67, 58, 51],
#  [75, 67, 58, 51],
#  [74, 67, 58, 55],
#  [74, 67, 58, 55],
#  [74, 67, 58, 55],
#  [74, 67, 58, 55],
#  [75, 67, 58, 53],
#  [75, 67, 58, 53],
#  [75, 67, 58, 51],
#  [75, 67, 58, 51],
#  [77, 65, 58, 50],
#  [77, 65, 58, 50],
#  [77, 65, 56, 50],
#  [77, 65, 56, 50],
#  [70, 63, 55, 51],
#  [70, 63, 55, 51],
#  [70, 63, 55, 51],
#  [70, 63, 55, 51],
#  [75, 65, 60, 45],
#  [75, 65, 60, 45],
#  [75, 65, 60, 45],
#  [75, 65, 60, 45],
#  [74, 65, 58, 46],
#  [74, 65, 58, 46],
#  [74, 65, 58, 46],
#  [74, 65, 58, 46],
#  [72, 65, 57, 53],
#  [72, 65, 57, 53],
#  [72, 65, 57, 53],
#  [72, 65, 57, 53],
#  [72, 65, 57, 53],
#  [72, 65, 57, 53],
#  [72, 65, 57, 53],
#  [72, 65, 57, 53],
#  [74, 65, 58, 58],
#  [74, 65, 58, 58],
#  [74, 65, 58, 58],
#  [74, 65, 58, 58],
#  [75, 67, 58, 57],
#  [75, 67, 58, 57],
#  [75, 67, 58, 55],
#  [75, 67, 58, 55],
#  [77, 65, 60, 57],
#  [77, 65, 60, 57],
#  [77, 65, 60, 53],
#  [77, 65, 60, 53],
#  [74, 65, 58, 58],
#  [74, 65, 58, 58],
#  [74, 65, 58, 58],
#  [74, 65, 58, 58],
#  [72, 67, 58, 51],
#  [72, 67, 58, 51],
#  [72, 67, 58, 51],
#  [72, 67, 58, 51],
#  [72, 65, 57, 53],
#  [72, 65, 57, 53],
#  [72, 65, 57, 53],
#  [72, 65, 57, 53],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46],
#  [70, 65, 62, 46]]

# %% [markdown]
# ## Baseline generation
# ### Collect data about distribution of values

# %%
data_sample = pd.read_csv(train_files[0])
cond = data_sample > 0
data_sample.where(cond,inplace=True)
lengths = []
lengths.append(data_sample.shape[0])

for file in train_files[1:]:
    f = pd.read_csv(file)
    cond = f > 0
    f.where(cond,inplace=True)
    lengths.append(f.shape[0])
    data_sample = data_sample.append(f)
    print(data_sample.shape)
# Out:
# (420, 4)
# (628, 4)
# (1060, 4)
# (1320, 4)
# (1532, 4)
# (1824, 4)
# (2004, 4)
# (2136, 4)
# (2328, 4)
# (2536, 4)
# (2808, 4)
# (3068, 4)
# (3200, 4)
# (3396, 4)
# (3852, 4)
# (4060, 4)
# (4512, 4)
# (4864, 4)
# (5060, 4)
# (5256, 4)
# (5480, 4)
# (5676, 4)
# (6060, 4)
# (6256, 4)
# (6648, 4)
# (6860, 4)
# (7072, 4)
# (7236, 4)
# (7432, 4)
# (7608, 4)
# (7740, 4)
# (7920, 4)
# (8020, 4)
# (8252, 4)
# (8512, 4)
# (8736, 4)
# (8896, 4)
# (9204, 4)
# (9464, 4)
# (9692, 4)
# (10032, 4)
# (10224, 4)
# (10556, 4)
# (10928, 4)
# (11232, 4)
# (11568, 4)
# (11808, 4)
# (12016, 4)
# (12164, 4)
# (12568, 4)
# (12812, 4)
# (13040, 4)
# (13172, 4)
# (13304, 4)
# (13576, 4)
# (13836, 4)
# (14096, 4)
# (14372, 4)
# (14504, 4)
# (14764, 4)
# (14960, 4)
# (15156, 4)
# (15384, 4)
# (15564, 4)
# (15792, 4)
# (15984, 4)
# (16140, 4)
# (16336, 4)
# (16564, 4)
# (16996, 4)
# (17128, 4)
# (17464, 4)
# (17768, 4)
# (17932, 4)
# (18448, 4)
# (18676, 4)
# (18868, 4)
# (19000, 4)
# (19240, 4)
# (19448, 4)
# (19676, 4)
# (19920, 4)
# (20180, 4)
# (20440, 4)
# (20744, 4)
# (20876, 4)
# (21296, 4)
# (21524, 4)
# (21688, 4)
# (22016, 4)
# (22276, 4)
# (22472, 4)
# (22700, 4)
# (22832, 4)
# (23052, 4)
# (23216, 4)
# (23520, 4)
# (23684, 4)
# (23944, 4)
# (24396, 4)
# (24604, 4)
# (24848, 4)
# (25044, 4)
# (25284, 4)
# (25480, 4)
# (25684, 4)
# (25944, 4)
# (26204, 4)
# (26496, 4)
# (26724, 4)
# (26900, 4)
# (27128, 4)
# (27472, 4)
# (27732, 4)
# (28072, 4)
# (28376, 4)
# (28552, 4)
# (28808, 4)
# (29096, 4)
# (29296, 4)
# (29460, 4)
# (29972, 4)
# (30232, 4)
# (30492, 4)
# (30812, 4)
# (31040, 4)
# (31300, 4)
# (31588, 4)
# (31848, 4)
# (32012, 4)
# (32208, 4)
# (32372, 4)
# (32632, 4)
# (32904, 4)
# (33068, 4)
# (33504, 4)
# (33892, 4)
# (34084, 4)
# (34328, 4)
# (34636, 4)
# (35044, 4)
# (35336, 4)
# (35544, 4)
# (35800, 4)
# (35996, 4)
# (36128, 4)
# (36460, 4)
# (36624, 4)
# (36876, 4)
# (37056, 4)
# (37204, 4)
# (37448, 4)
# (37752, 4)
# (37932, 4)
# (38192, 4)
# (38388, 4)
# (38580, 4)
# (38868, 4)
# (39176, 4)
# (39308, 4)
# (39584, 4)
# (40064, 4)
# (40196, 4)
# (40440, 4)
# (40700, 4)
# (40960, 4)
# (41092, 4)
# (41288, 4)
# (41548, 4)
# (41800, 4)
# (41992, 4)
# (42200, 4)
# (42464, 4)
# (42660, 4)
# (42876, 4)
# (43068, 4)
# (43260, 4)
# (43532, 4)
# (43696, 4)
# (44132, 4)
# (44392, 4)
# (44648, 4)
# (44876, 4)
# (45068, 4)
# (45324, 4)
# (45584, 4)
# (45824, 4)
# (46112, 4)
# (46308, 4)
# (46488, 4)
# (46748, 4)
# (46940, 4)
# (47072, 4)
# (47316, 4)
# (47592, 4)
# (47864, 4)
# (48060, 4)
# (48240, 4)
# (48436, 4)
# (48696, 4)
# (49000, 4)
# (49196, 4)
# (49360, 4)
# (49524, 4)
# (49752, 4)
# (49996, 4)
# (50160, 4)
# (50372, 4)
# (50728, 4)
# (50860, 4)
# (51116, 4)
# (51500, 4)
# (51728, 4)
# (51984, 4)
# (52212, 4)
# (52404, 4)
# (52708, 4)
# (52840, 4)
# (53036, 4)
# (53292, 4)
# (53728, 4)
# (53988, 4)
# (54248, 4)
# (54492, 4)
# (54688, 4)
# (54836, 4)
# (55064, 4)
# (55228, 4)

# %%
pd.Series(lengths).describe()
# Out:
# count    229.000000
# mean     241.170306
# std       78.130524
# min      100.000000
# 25%      192.000000
# 50%      228.000000
# 75%      260.000000
# max      516.000000
# dtype: float64

# %%
data_sample.describe()
# Out:
#               note0         note1         note2         note3
# count  55155.000000  55132.000000  55110.000000  55104.000000
# mean      70.416263     64.979903     59.462856     50.637921
# std        3.672974      3.192862      3.328952      4.764402
# min       60.000000     52.000000     46.000000     36.000000
# 25%       68.000000     62.000000     57.000000     47.000000
# 50%       71.000000     65.000000     59.000000     50.000000
# 75%       73.000000     67.000000     62.000000     54.000000
# max       81.000000     74.000000     69.000000     66.000000

# %% [markdown]
# ### Random generator which uses collected data as parameters

# %%
rng = np.random.default_rng()

def generate_random_bach(n_steps):
    #length = rng.integers(100, 517)
    n0 = rng.integers(60, 82, size=n_steps)
    n1 = rng.integers(52, 75, size=n_steps)    
    n2 = rng.integers(46, 70, size=n_steps)    
    n3 = rng.integers(36, 67, size=n_steps)    
    
    generated = np.stack((n0,n1,n2,n3),axis=-1)

    return generated

# %%
gen1 = generate_random_bach(10)
gen1.shape
# Out:
# (10, 4)

# %% [markdown]
# ## First simple RNN model

# %%
import keras

simple_seq = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None,4]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.Dense(1)
])
# Out:
# Using TensorFlow backend.

# %%
train_prep = preprocess_and_batch(train_data)
valid_prep = preprocess_and_batch(valid_data)
test_prep = preprocess_and_batch(test_data)
train_prep
# Out:
# chorales: <tf.RaggedTensor [[[74, 70, 65, 58], [74, 70, 65, 58], [74, 70, 65, 58], [74, 70, 65, 58], [75, 70, 58, 55], [75, 70, 58, 55], [75, 70, 60, 55], [75, 70, 60, 55], [77, 69, 62, 50], [77, 69, 62, 50], [77, 69, 62, 50], [77, 69, 62, 50], [77, 70, 62, 55], [77, 70, 62, 55], [77, 69, 62, 55], [77, 69, 62, 55], [75, 67, 63, 48], [75, 67, 63, 48], [75, 69, 63, 48], [75, 69, 63, 48], [74, 70, 65, 46], [74, 70, 65, 46], [74, 70, 65, 46], [74, 70, 65, 46], [72, 69, 65, 53], [72, 69, 65, 53], [72, 69, 65, 53], [72, 69, 65, 53], [72, 69, 65, 53], [72, 69, 65, 53], [72, 69, 65, 53], [72, 69, 65, 53], [74, 70, 65, 46], [74, 70, 65, 46], [74, 70, 65, 46], [74, 70, 65, 46], [75, 69, 63, 48], [75, 69, 63, 48], [75, 67, 63, 48], [75, 67, 63, 48], [77, 65, 62, 50], [77, 65, 62, 50], [77, 65, 60, 50], [77, 65, 60, 50], [74, 67, 58, 55], [74, 67, 58, 55], [74, 67, 58, 53], [74, 67, 58, 53], [72, 67, 58, 51], [72, 67, 58, 51], [72, 67, 58, 51], [72, 67, 58, 51], [72, 65, 57, 53], [72, 65, 57, 53], [72, 65, 57, 53], [72, 65, 57, 53], [70, 65, 62, 46], [70, 65, 62, 46], [70, 65, 62, 46], [70, 65, 62, 46], [70, 65, 62, 46], [70, 65, 62, 46], [70, 65, 62, 46], [70, 65, 62, 46], [72, 69, 65, 53], [72, 69, 65, 53], [72, 69, 65, 53], [72, 69, 65, 53], [74, 71, 53, 50], [74, 71, 53, 50], [74, 71, 53, 50], [74, 71, 53, 50], [75, 72, 55, 48], [75, 72, 55, 48], [75, 72, 55, 50], [75, 72, 55, 50], [75, 67, 60, 51], [75, 67, 60, 51], [75, 67, 60, 53], [75, 67, 60, 53], [74, 67, 60, 55], [74, 67, 60, 55], [74, 67, 57, 55], [74, 67, 57, 55], [74, 65, 59, 43], [74, 65, 59, 43], [72, 63, 59, 43], [72, 63, 59, 43], [72, 63, 55, 48], [72, 63, 55, 48], [72, 63, 55, 48], [72, 63, 55, 48], [72, 63, 55, 48], [72, 63, 55, 48], [72, 63, 55, 48], [72, 63, 55, 48], [75, 67, 60, 60], [75, 67, 60, 60], [75, 67, 60, 60], [75, 67, 60, 60], [77, 70, 62, 58], [77, 70, 62, 58], [77, 70, 62, 56], [77, 70, 62, 56], [79, 70, 62, 55], [79, 70, 62, 55], [79, 70, 62, 53], [79, 70, 62, 53], [79, 70, 63, 51], [79, 70, 63, 51], [79, 70, 63, 51], [79, 70, 63, 51], [77, 70, 63, 58], [77, 70, 63, 58], [77, 70, 60, 58], [77, 70, 60, 58], [77, 70, 62, 46], [77, 70, 62, 46], [77, 68, 62, 46], [75, 68, 62, 46], [75, 67, 58, 51], [75, 67, 58, 51], [75, 67, 58, 51], [75, 67, 58, 51], [75, 67, 58, 51], [75, 67, 58, 51], [75, 67, 58, 51], [75, 67, 58, 51], [74, 67, 58, 55], [74, 67, 58, 55], [74, 67, 58, 55], [74, 67, 58, 55], [75, 67, 58, 53], [75, 67, 58, 53], [75, 67, 58, 51], [75, 67, 58, 51], [77, 65, 58, 50], [77, 65, 58, 50], [77, 65, 56, 50], [77, 65, 56, 50], [70, 63, 55, 51], [70, 63, 55, 51], [70, 63, 55, 51], [70, 63, 55, 51], [75, 65, 60, 45], [75, 65, 60, 45], [75, 65, 60, 45], [75, 65, 60, 45], [74, 65, 58, 46], [74, 65, 58, 46], [74, 65, 58, 46], [74, 65, 58, 46], [72, 65, 57, 53], [72, 65, 57, 53], [72, 65, 57, 53], [72, 65, 57, 53], [72, 65, 57, 53], [72, 65, 57, 53], [72, 65, 57, 53], [72, 65, 57, 53], [74, 65, 58, 58], [74, 65, 58, 58], [74, 65, 58, 58], [74, 65, 58, 58], [75, 67, 58, 57], [75, 67, 58, 57], [75, 67, 58, 55], [75, 67, 58, 55], [77, 65, 60, 57], [77, 65, 60, 57], [77, 65, 60, 53], [77, 65, 60, 53], [74, 65, 58, 58], [74, 65, 58, 58], [74, 65, 58, 58], [74, 65, 58, 58], [72, 67, 58, 51], [72, 67, 58, 51], [72, 67, 58, 51], [72, 67, 58, 51], [72, 65, 57, 53], [72, 65, 57, 53], [72, 65, 57, 53], [72, 65, 57, 53], [70, 65, 62, 46], [70, 65, 62, 46], [70, 65, 62, 46], [70, 65, 62, 46], [70, 65, 62, 46], [70, 65, 62, 46], [70, 65, 62, 46], [70, 65, 62, 46]], [[69, 64, 61, 57], [69, 64, 61, 57], [69, 64, 61, 57], [69, 64, 61, 57], [71, 64, 59, 56], [71, 64, 59, 56], [71, 64, 57, 54], [71, 64, 57, 54], [71, 64, 56, 52], [71, 64, 56, 52], [71, 64, 56, 50], [71, 64, 56, 50], [69, 64, 57, 49], [69, 64, 57, 49], [69, 64, 57, 49], [69, 64, 57, 49], [66, 62, 57, 50], [66, 62, 57, 50], [66, 61, 57, 50], [66, 61, 57, 50], [64, 59, 56, 50], [64, 59, 56, 50], [64, 59, 56, 50], [64, 59, 56, 50], [66, 61, 57, 49], [66, 61, 57, 49], [68, 62, 59, 47], [68, 62, 59, 47], [69, 64,  ...
# RaggedTensorSpec(TensorShape([None, 4]), tf.int32, 0, tf.int64)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-e47e4042400f> in <module>
# ----> 1 train_prep = preprocess_and_batch(train_data)
#       2 valid_prep = preprocess_and_batch(valid_data)
#       3 test_prep = preprocess_and_batch(test_data)
#       4 train_prep
#
# <ipython-input-40-f8582e420ca5> in preprocess_and_batch(chorales, window_size, window_shift, batch_size)
#      30     chorale_ds = tf.data.Dataset.from_tensor_slices(chorales)
#      31     print(chorale_ds.element_spec)
# ---> 32     chorale_ds = chorale_ds.flat_map(create_window).map(preprocess_chords)
#      33     chorale_ds = chorale_ds.batch(batch_size)
#      34     chorale_ds = chorale_ds.map(extract_target)
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\data\ops\dataset_ops.py in flat_map(self, map_func)
#    1238       Dataset: A `Dataset`.
#    1239     """
# -> 1240     return FlatMapDataset(self, map_func)
#    1241
#    1242   def interleave(self,
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func)
#    3484     self._input_dataset = input_dataset
#    3485     self._map_func = StructuredFunctionWrapper(
# -> 3486         map_func, self._transformation_name(), dataset=input_dataset)
#    3487     if not isinstance(self._map_func.output_structure, DatasetSpec):
#    3488       raise TypeError(
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\data\ops\dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    2693       resource_tracker = tracking.ResourceTracker()
#    2694       with tracking.resource_tracker_scope(resource_tracker):
# -> 2695         self._function = wrapper_fn._get_concrete_function_internal()
#    2696         if add_to_graph:
#    2697           self._function.add_to_graph(ops.get_default_graph())
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\eager\function.py in _get_concrete_function_internal(self, *args, **kwargs)
#    1852     """Bypasses error checking when getting a graph function."""
#    1853     graph_function = self._get_concrete_function_internal_garbage_collected(
# -> 1854         *args, **kwargs)
#    1855     # We're returning this concrete function to someone, and they may keep a
#    1856     # reference to the FuncGraph without keeping a reference to the
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    1846     if self.input_signature:
#    1847       args, kwargs = None, None
# -> 1848     graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    1849     return graph_function
#    1850
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    2148         graph_function = self._function_cache.primary.get(cache_key, None)
#    2149         if graph_function is None:
# -> 2150           graph_function = self._create_graph_function(args, kwargs)
#    2151           self._function_cache.primary[cache_key] = graph_function
#    2152         return graph_function, args, kwargs
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    2039             arg_names=arg_names,
#    2040             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 2041             capture_by_value=self._capture_by_value),
#    2042         self._function_attributes,
#    2043         # Tell the ConcreteFunction to clean up its graph once it goes out of
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     913                                           converted_func)
#     914
# --> 915       func_outputs = python_func(*func_args, **func_kwargs)
#     916
#     917       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\data\ops\dataset_ops.py in wrapper_fn(*args)
#    2687           attributes=defun_kwargs)
#    2688       def wrapper_fn(*args):  # pylint: disable=missing-docstring
# -> 2689         ret = _wrapper_helper(*args)
#    2690         ret = structure.to_tensor_list(self._output_structure, ret)
#    2691         return [ops.convert_to_tensor(t) for t in ret]
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\data\ops\dataset_ops.py in _wrapper_helper(*args)
#    2628       """Wrapper for passing nested structures to and from tf.data functions."""
#    2629       nested_args = structure.from_compatible_tensor_list(
# -> 2630           self._input_structure, args)
#    2631       if not _should_unpack_args(nested_args):
#    2632         nested_args = (nested_args,)
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\data\util\structure.py in from_compatible_tensor_list(element_spec, tensor_list)
#     224   return _from_tensor_list_helper(
#     225       lambda spec, value: spec._from_compatible_tensor_list(value),
# --> 226       element_spec, tensor_list)
#     227
#     228
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\data\util\structure.py in _from_tensor_list_helper(decode_fn, element_spec, tensor_list)
#     199   for (component_spec, num_flat_values) in zip(flat_specs, flat_spec_lengths):
#     200     value = tensor_list[i:i + num_flat_values]
# --> 201     flat_ret.append(decode_fn(component_spec, value))
#     202     i += num_flat_values
#     203   return nest.pack_sequence_as(element_spec, flat_ret)
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\data\util\structure.py in <lambda>(spec, value)
#     223   # pylint: disable=g-long-lambda
#     224   return _from_tensor_list_helper(
# --> 225       lambda spec, value: spec._from_compatible_tensor_list(value),
#     226       element_spec, tensor_list)
#     227
#
# ~\Anaconda3\envs\tf2\lib\site-packages\tensorflow_core\python\ops\ragged\ragged_tensor.py in _from_compatible_tensor_list(self, tensor_list)
#    2025     if self._ragged_rank <= 0:
#    2026       raise ValueError(
# -> 2027           "ragged_rank must be non-negative; got %s." % self._ragged_rank)
#    2028     result = RaggedTensor._from_variant(  # pylint: disable=protected-access
#    2029         tensor_list[0], dtype=self._dtype,
#
# ValueError: ragged_rank must be non-negative; got 0.
